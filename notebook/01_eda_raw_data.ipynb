# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col

# %%
spark = SparkSession.builder \
        .appName("Ecommerce-Analytics-EDA") \
        .master("local[*]") \
        .config("spark.driver.memory", "6g") \
        .config("spark.executor.memory", "6g") \
        .config("spark.sql.shuffle.partitions", "200") \
        .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/05/31 22:24:16 WARN Utils: Your hostname, Liu, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/05/31 22:24:16 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/05/31 22:24:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
raw_data = "../data/raw_data/01-log-tracking.csv"
bronze_output = "../data/bronze/"

# %%
df = spark.read.csv(raw_data, header=True)

# %%
df.show(1)
# Out:
# +--------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# |          event_time|event_type|product_id|        category_id|       category_code| brand| price|  user_id|        user_session|
# +--------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# |2019-11-01 00:00:...|      view|   1003461|2053013555631882655|electronics.smart...|xiaomi|489.07|520088904|4d3b30da-a5e4-49d...|
# +--------------------+----------+----------+-------------------+--------------------+------+------+---------+--------------------+
# only showing top 1 row

# %%
df.printSchema()
# Out:
# root
#  |-- event_time: string (nullable = true)
#  |-- event_type: string (nullable = true)
#  |-- product_id: string (nullable = true)
#  |-- category_id: string (nullable = true)
#  |-- category_code: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- user_id: string (nullable = true)
#  |-- user_session: string (nullable = true)

# %%
# Checking for missing values
for column in df.columns:
    null_count = df.filter(col(column).isNull()).count()
    print(f'Column {column}: {null_count} null values')
# Out:
# Column event_time: 0 null values
# Column event_type: 0 null values
# Column product_id: 0 null values
# Column category_id: 0 null values
# Column category_code: 21898171 null values
# Column brand: 9218235 null values
# Column price: 0 null values
# Column user_id: 0 null values
# [Stage 26:=====================================================>  (65 + 3) / 68]
# Column user_session: 10 null values

# %%
spark.stop()
